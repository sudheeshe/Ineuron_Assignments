# %% [markdown]
# ### 1. Using our own terms and diagrams, explain INCEPTIONNET ARCHITECTURE.

# %% [markdown]
# `Inception Net`
#
# - Inception Net tried to solve simple but powerful way of creating better deep learning models. You can just make a bigger model, either in terms of deepness, i.e., number of layers, or the number of neurons in each layer. But as you can imagine, this can often create complications:
#
#       1)Bigger the model, more prone it is to overfitting. This is particularly noticeable when the training data is small
#
#       2)Increasing the number of parameters means you need to increase your existing computational resources

# %% [markdown]
# - A solution for this, as the paper suggests, is to move on to sparsely connected network architectures which will replace fully connected network architectures, especially inside convolutional layers. This idea can be conceptualized in the below images:
#
# Densely connected architecture
#
# ![Screenshot-from-2018-10-16-10-52-13-206x300.png](attachment:Screenshot-from-2018-10-16-10-52-13-206x300.png)

# %% [markdown]
# Sparsely connected architecture
#
# ![Screenshot-from-2018-10-16-10-52-30-300x165.png](attachment:Screenshot-from-2018-10-16-10-52-30-300x165.png)

# %% [markdown]
# This paper proposes a new idea of creating deep architectures. This approach lets you maintain the “computational budget”, while increasing the depth and width of the network. Sounds too good to be true! This is how the conceptualized idea looks:
#
# ![googlenet.webp](attachment:googlenet.webp)

# %% [markdown]
# The paper proposes a new type of architecture – GoogLeNet or Inception v1. It is basically a convolutional neural network (CNN) which is 27 layers deep. Below is the model summary:
#
# ![Screenshot-from-2018-10-16-11-24-42-109x440.webp](attachment:Screenshot-from-2018-10-16-11-24-42-109x440.webp)

# %% [markdown]
# Notice in the above image that there is a layer called inception layer. This is actually the main idea behind the paper’s approach. The inception layer is the core concept of a sparsely connected architecture.
#
# ![Screenshot-from-2018-10-16-10-52-30-300x1651-300x165.png](attachment:Screenshot-from-2018-10-16-10-52-30-300x1651-300x165.png)

# %% [markdown]
# - (Inception Layer) is a combination of all those layers (namely, 1×1 Convolutional layer, 3×3 Convolutional layer, 5×5 Convolutional layer) with their output filter banks concatenated into a single output vector forming the input of the next stage
#
# - Along with the above-mentioned layers, there are two major add-ons in the original inception layer:
#
#         1) 1×1 Convolutional layer before applying another layer, which is mainly used for dimensionality reduction
#         2) A parallel Max Pooling layer, which provides another option to the inception layer
#
#  ![Screenshot-from-2018-10-17-11-14-10.webp](attachment:Screenshot-from-2018-10-17-11-14-10.webp)

# %% [markdown]
# `Inception Layer`
#
# To understand the importance of the inception layer’s structure, the author calls on the Hebbian principle from human learning. This says that “neurons that fire together, wire together”. The author suggests that when creating a subsequent layer in a deep learning model, one should pay attention to the learnings of the previous layer.
#
# Suppose, for example, a layer in our deep learning model has learned to focus on individual parts of a face. The next layer of the network would probably focus on the overall face in the image to identify the different objects present there. Now to actually do this, the layer should have the appropriate filter sizes to detect different objects.
#
# ![cat_vs_dog_explain4.webp](attachment:cat_vs_dog_explain4.webp)

# %% [markdown]
# This is where the inception layer comes to the fore. It allows the internal layers to pick and choose which filter size will be relevant to learn the required information. So even if the size of the face in the image is different (as seen in the images below), the layer works accordingly to recognize the face. For the first image, it would probably take a higher filter size, while it’ll take a lower one for the second image.
#
# ![Screenshot-from-2018-10-17-11-42-40-768x264.webp](attachment:Screenshot-from-2018-10-17-11-42-40-768x264.webp)

# %% [markdown]
# The overall architecture, with all the specifications, looks like this:
#
#  ![Screenshot-from-2018-10-16-11-56-41.webp](attachment:Screenshot-from-2018-10-16-11-56-41.webp)

# %% [markdown]
# ### 2. Describe the Inception block.

# %% [markdown]
# (Inception Layer) is a combination of all those layers (namely, 1×1 Convolutional layer, 3×3 Convolutional layer, 5×5 Convolutional layer) with their output filter banks concatenated into a single output vector forming the input of the next stage.
#
# An Inception Module is an image model block that aims to approximate an optimal local sparse structure in a CNN. Put simply, it allows for us to use multiple types of filter size, instead of being restricted to a single filter size, in a single image block, which we then concatenate and pass onto the next layer.

# %% [markdown]
# ### 3. What is the DIMENSIONALITY REDUCTION LAYER (1 LAYER CONVOLUTIONAL)?

# %% [markdown]
# A 1x1 convolution simply maps an input pixel with all it's channels to an output pixel, not looking at anything around itself. It is often used to reduce the number of depth channels, since it is often very slow to multiply volumes with extremely large depths.

# %% [markdown]
# ### 4. THE IMPACT OF REDUCING DIMENSIONALITY ON NETWORK PERFORMANCE

# %% [markdown]
# It reduces the time and storage space required. The removal of multicollinearity improves the interpretation of the parameters of the machine learning model. It becomes easier to visualize the data when reduced to very low dimensions such as 2D or 3D. Reduce space complexity.

# %% [markdown]
# ### 5. Mention three components. Style GoogLeNet

# %% [markdown]
# - Inception Module
#
# - Local Response Normalization
#
# - Max Pooling

# %% [markdown]
# ### 6. Using our own terms and diagrams, explain RESNET ARCHITECTURE.

# %% [markdown]
# - Resnet solved problem when the deep learning architectures became deeper and deeper (adding more layers) to solve more and more complex tasks which also helped in improving the performance of classification and recognition tasks and also making them robust.
#
# `Residual Blocks`
# - The problem of training very deep networks has been relieved with the introduction of these Residual blocks and the ResNet model is made up of these blocks.
#
# ![63071n1.png](attachment:63071n1.png)

# %% [markdown]
# - he problem of training very deep networks has been relieved with the introduction of these Residual blocks and the ResNet model is made up of these blocks.
#
# - In the above figure, the very first thing we can notice is that there is a direct connection that skips some layers of the model. This connection is called ’skip connection’ and is the heart of residual blocks. The output is not the same due to this skip connection. Without the skip connection, input ‘X gets multiplied by the weights of the layer followed by adding a bias term.
#
# - Then comes the activation function, f() and we get the output as H(x).
#
# `H(x)=f( wx + b ) or H(x)=f(x)`
#
# - Now with the introduction of a new skip connection technique, the output is H(x) is changed to
#
# `H(x)=f(x)+x`
#
# - But the dimension of the input may be varying from that of the output which might happen with a convolutional layer or pooling layers. Hence, this problem can be handled with these two approaches:
#
#                 · Zero is padded with the skip connection to increase its dimensions.
#
#                 · 1×1 convolutional layers are added to the input to match the dimensions. In such a case, the output is:
#
# `H(x)=f(x)+w1.x`
#
# - Here an additional parameter w1 is added whereas no additional parameter is added when using the first approach.
#
# - These skip connections technique in ResNet solves the problem of vanishing gradient in deep CNNs by allowing alternate shortcut path for the gradient to flow through. Also, the skip connection helps if any layer hurts the performance of architecture, then it will be skipped by regularization.

# %% [markdown]
# - There is a 34-layer plain network in the architecture that is inspired by VGG-19 in which the shortcut connection or the skip connections are added. These skip connections or the residual blocks then convert the architecture into the residual network as shown in the figure below.
#
# ![28984n2.png](attachment:28984n2.png)

# %% [markdown]
# ### 7. What do Skip Connections entail?

# %% [markdown]
# - While training deep neural nets, the performance of the model drops down with the increase in depth of the architecture. This is known as the degradation problem. But, what could be the reasons for the saturation inaccuracy with the increase in network depth? Let us try to understand the reasons behind the degradation problem.
#
# - One of the possible reasons could be overfitting. The model tends to overfit with the increase in depth but that’s not the case here.  As you can infer from the below figure, the deeper network with 56 layers has more training error than the shallow one with 20 layers. The deeper model doesn’t perform as well as the shallow one.  Clearly, overfitting is not the problem here.
#
# - Skip Connections (or Shortcut Connections) as the name suggests skips some of the layers in the neural network and feeds the output of one layer as the input to the next layers.
#
# - Skip Connections were introduced to solve different problems in different architectures. In the case of ResNets, skip connections solved the degradation problem that we addressed earlier whereas, in the case of DenseNets, it ensured feature reusability.

# %% [markdown]
# ### 8. What is the definition of a residual Block?

# %% [markdown]
# Residual Blocks are skip-connection blocks that learn residual functions with reference to the layer inputs, instead of learning unreferenced functions. They were introduced as part of the ResNet architecture.

# %% [markdown]
# ### 9. How can transfer learning help with problems?

# %% [markdown]
# Transfer learning is generally used: To save time and resources from having to train multiple machine learning models from scratch to complete similar tasks. As an efficiency saving in areas of machine learning that require high amounts of resources such as image categorisation or natural language processing

# %% [markdown]
# ### 10. What is transfer learning, and how does it work?

# %% [markdown]
# - The reuse of a previously learned model on a new problem is known as transfer learning. It’s particularly popular in deep learning right now since it can train deep neural networks with a small amount of data.
#
# - The reuse of a previously learned model on a new problem is known as transfer learning. It’s particularly popular in deep learning right now since it can train deep neural networks with a small amount of data.

# %% [markdown]
# ### 11. HOW DO NEURAL NETWORKS LEARN FEATURES?

# %% [markdown]
# CNN is designed to automatically and adaptively learn spatial hierarchies of features through backpropagation by using multiple building blocks, such as convolution layers, pooling layers, and fully connected layers.

# %% [markdown]
# ### 12. WHY IS FINE-TUNING BETTER THAN START-UP TRAINING?

# %% [markdown]
# Learning from scratch is a building completely a new model or mixing parts of others, and do training from the first layer. Fine tuning of the network is the process when you adjust parameters such as a learning rate, the number of epochs, the optimizer, regularization parameters etc. to achieve best possible results.
#
#
# If the trained model is trained on a similar problem, then fine tuning the model to the current domain problem is highly recommaned. or else if the problem is entirely a different use case, then we need to train the model from scratch. that gives the model better performance.
