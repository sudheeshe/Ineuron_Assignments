# %% [markdown]
# ### 1. Using a graph to illustrate slope and intercept, define basic linear regression.

# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)

# %% [markdown]
# Linear regression algorithm shows a linear relationship between a dependent (y) and one or more independent (y) variables, hence called as linear regression. Since linear regression shows the linear relationship, which means it finds how the value of the dependent variable is changing according to the value of the independent variable.
#
# ![linear-regression-in-machine-learning.png](attachment:linear-regression-in-machine-learning.png)

# %% [markdown]
# ### 2. In a graph, explain the terms rise, run, and slope.

# %% [markdown]
# ![blog-understanding-slope-how-it-is-measured-B1.webp](attachment:blog-understanding-slope-how-it-is-measured-B1.webp)

# %% [markdown]
# Slope = Rise/ Run

# %% [markdown]
# ### 3. Use a graph to demonstrate slope, linear positive slope, and linear negative slope, as well as the different conditions that contribute to the slope.

# %% [markdown]
# ![download%20%282%29.png](attachment:download%20%282%29.png)

# %% [markdown]
# ![download%20%283%29.png](attachment:download%20%283%29.png)

# %% [markdown]
# ### 4. Use a graph to demonstrate curve linear negative slope and curve linear positive slope.

# %% [markdown]
# ### 5. Use a graph to show the maximum and low points of curves.

# %% [markdown]
# ![max-min-curve-26n6kwa.jpg](attachment:max-min-curve-26n6kwa.jpg)

# %% [markdown]
# ### 6. Use the formulas for a and b to explain ordinary least squares.

# %% [markdown]
# The OLS method is used to estimate β0 and β1. The OLS method seeks to minimize the sum of the squared residuals. This means from the given data we calculate the distance from each data point to the regression line, square it, and the sum of all of the squared errors together.
#
# ![0_gglavDlTUWKn4Loe.png](attachment:0_gglavDlTUWKn4Loe.png)

# %% [markdown]
# ### 7. Provide a step-by-step explanation of the OLS algorithm.

# %% [markdown]
# Ordinary Least Squares regression (OLS) is a common technique for estimating coefficients of linear regression equations which describe the relationship between one or more independent quantitative variables and a dependent variable (simple or multiple linear regression). Least squares stand for the minimum squares error (SSE). Maximum likelihood and Generalized method of moments estimator are alternative approaches to OLS.

# %% [markdown]
# Let us start with notation.
#
# - `X` is data of independent variable from observation
#
# - `a` is the mean of `X`
#
# - `Y` is data of dependent variable from observation
#
# - `b` is the mean of`Y`
#
# - `ŷ` is the estimated of `Y` ,that is represented by the regression model.
#
# - `n` is the number of observation data

# %% [markdown]
# To perform ordinary least square method,you do the following steps:
#
#   1. Set a difference between dependent variable and its estimation: `(Y-ŷ)`
#
#   2. Square the difference: `(Y-ŷ)²`
#
#   3. Take summation for all data: `S=Σ(y->)²`
#
#   4. To get the parameters that make the sum of square difference become minimum,take partial derivative for each parameter and equate it with zero

# %% [markdown]
# ### 8. What is the regression's standard error? To represent the same, make a graph.

# %% [markdown]
# ![1548351208631.webp](attachment:1548351208631.webp)

# %% [markdown]
# ### 9. Provide an example of multiple linear regression.

# %% [markdown]
# Predicting Sales based with respect to marketing_cost, cost on supplychain, price_of_product, etc..

# %% [markdown]
# ### 10. Describe the regression analysis assumptions and the BLUE principle.

# %% [markdown]
# BLUE is an acronym for the following: Best Linear Unbiased Estimator. In this context, the definition of “best” refers to the minimum variance or the narrowest sampling distribution.

# %% [markdown]
# Linear regression is an analysis that assesses whether one or more predictor variables explain the dependent (criterion) variable.  The regression has five key assumptions:
#
# - Linear relationship
# - Multivariate normality
# - No or little multicollinearity
# - No auto-correlation
# - Homoscedasticity

# %% [markdown]
# ### 11. Describe two major issues with regression analysis.

# %% [markdown]
# - Heteroskedasticity:  variance of error term is not constant.Test using BP test BP=nR2
#
#
# - Serial correlation:error terms are correlated.Test using DW stat. DW2 = (1-r)
#
#
# - Multicollinearity:two or more independent variables are highly correlated.

# %% [markdown]
# ### 12. How can the linear regression model's accuracy be improved?

# %% [markdown]
# - Handling Null/Missing Values.
#
# - Data Visualization.
#
# - Feature Selection and Scaling. (Feature Engineering. & Feature Transformation.)
#
# - Use of Ensemble and Boosting Algorithms.
#
# - Hyperparameter Tuning.

# %% [markdown]
# ### 13. Using an example, describe the polynomial regression model in detail.

# %% [markdown]
# In simple linear regression algorithm only works when the relationship between the data is linear But suppose if we have non-linear data then Linear regression will not capable to draw a best-fit line and It fails in such conditions. consider the below diagram which has a non-linear relationship and you can see the Linear regression results on it, which does not perform well means which do not comes close to reality. Hence, we introduce polynomial regression to overcome this problem, which helps identify the curvilinear relationship between independent and dependent variables.

# %% [markdown]
# ![kawer8rc.5_%285%29.png](attachment:kawer8rc.5_%285%29.png)

# %% [markdown]
# Polynomial regression is a form of Linear regression where only due to the Non-linear relationship between dependent and independent variables we add some polynomial terms to linear regression to convert it into Polynomial regression.
#
# Suppose we have X as Independent data and Y as dependent data. Before feeding data to a mode in preprocessing stage we convert the input variables into polynomial terms using some degree.

# %% [markdown]
# For example, it is widely applied to predict the spread rate of COVID-19 and other infectious diseases.

# %% [markdown]
# ### 14. Provide a detailed explanation of logistic regression.

# %% [markdown]
# `Logistic Regression`
#
# It is a predictive algorithm using independent variables to predict the dependent variable, just like Linear Regression, but with a difference that the dependent variable should be categorical variable.
#
# Independent variables can be numeric or categorical variables, but the dependent variable will always be categorical

# %% [markdown]
# For binary regression, we calculate the conditional probability of the dependent variable Y, given independent variable X
#
# It can be written as `P(Y=1|X) or P(Y=0|X)`
#
# This is read as the conditional probability of Y=1, given X or conditional probability of Y=0, given X.
#
# P(Y |X) is approximated as a sigmoid function applied to a linear combination of input features

# %% [markdown]
# `Assumptions for Logistic Regression`
#
# - No outliers in the data. An outlier can be identified by analyzing the independent variables
# - No correlation (multi-collinearity) between the independent variables.

# %% [markdown]
# `Logistic Regression function`
#
# Logistic regression uses logit function, also referred to as log-odds; it is the logarithm of odds. The odds ratio is the ratio of odds of an event A in the presence of the event B and the odds of event A in the absence of event B.
#
# ![1_J3ydXZrpJdXefOmx9YIdaQ.png](attachment:1_J3ydXZrpJdXefOmx9YIdaQ.png)
#
#
# P is the probability that event Y occurs. P(Y=1)
# P/(1-P) is the odds ratio
# θ is a parameters of length m
# Logit function estimates probabilities between 0 and 1, and hence logistic regression is a non-linear transformation that looks like S- function shown below.

# %% [markdown]
# ![1_LOre2iyY2Q64VR2_AareWA.png](attachment:1_LOre2iyY2Q64VR2_AareWA.png)
#
# Logistic Regression function
# The parameter “θ” of the logistic function can be estimated using the maximum likelihood estimation(MLE) framework. MLE searches for the parameters that best fit the joint probability if the independent variables X.
#
# MLE will give us values for parameter “θ” that would maximize the probability close to 1 for the person who would default their payment and a number close to 0 for all individuals who would not default their payment.

# %% [markdown]
# ### 15. What are the logistic regression assumptions?

# %% [markdown]
# `Assumptions for Logistic Regression`
#
# - No outliers in the data. An outlier can be identified by analyzing the independent variables
# - No correlation (multi-collinearity) between the independent variables.

# %% [markdown]
# ### 16. Go through the details of maximum likelihood estimation.

# %% [markdown]
# Maximum Likelihood Estimation is a probabilistic framework for solving the problem of density estimation. It involves maximizing a likelihood function in order to find the probability distribution and parameters that best explain the observed data.

# %% [markdown]
# Maximum likelihood estimation is a method that determines values for the parameters of a model. The parameter values are found such that they maximise the likelihood that the process described by the model produced the data that were actually observed.
