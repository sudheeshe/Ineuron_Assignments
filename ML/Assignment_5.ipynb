# %% [markdown]
# ### 1. What are the key tasks that machine learning entails? What does data pre-processing imply?

# %% [markdown]
# Machine Learning is gaining some useful information from the data.
#
# Data preprocessing is essential before its actual use. Data preprocessing is the concept of changing the raw data into a clean data set. The dataset is preprocessed in order to check missing values, noisy data, and other inconsistencies before executing it to the algorithm.

# %% [markdown]
# ### 2. Describe quantitative and qualitative data in depth. Make a distinction between the two.

# %% [markdown]
# Quantitative data is numbers-based, countable, or measurable. Qualitative data is interpretation-based, descriptive, and relating to language. Quantitative data tells us how many, how much, or how often in calculations. Qualitative data can help us to understand why, how, or what happened behind certain behaviors.
#
#
# To acquire qualitative data, consider identifiers like the color of your clothes, type of hair, and nose shape. For quantitative data, consider measurable values like your height, weight, age, and shoe size.

# %% [markdown]
# ### 3. Create a basic data collection that includes some sample records. Have at least one attribute from each of the machine learning data types.

# %% [markdown]
# ### Answer:

# %% [markdown]
# ![Screenshot%202022-06-18%20211732.jpg](attachment:Screenshot%202022-06-18%20211732.jpg)

# %% [markdown]
# ### 4. What are the various causes of machine learning data issues? What are the ramifications?

# %% [markdown]
# 1. `Inadequate Training Data:`
#
#     - `Noisy Data` - It is responsible for an inaccurate prediction that affects the decision as well as accuracy in classification tasks.
#
#     - `Incorrect data` - It is also responsible for faulty programming and results obtained in machine learning models. Hence, incorrect data may affect the accuracy of the results also.
#
#     - `Generalizing of output data`- Sometimes, it is also found that generalizing output data becomes complex, which results in comparatively poor future actions.
#
#
# 2. `Poor quality of data:`
#
# 3. `Non-representative training data:`
#
# 4. `Data Bias:`
#
#             Data Biasing is also found a big challenge in Machine Learning. These errors exist when certain elements of the dataset are heavily weighted or need more importance than others. Biased data leads to inaccurate results, skewed outcomes, and other analytical errors.

# %% [markdown]
# ### 5. Demonstrate various approaches to categorical data exploration with appropriate examples.

# %% [markdown]
# Bar Charts, Bar Graph, Pie Charts,

# %% [markdown]
# ### 6. How would the learning activity be affected if certain variables have missing values ? Having said that, what can be done about it ?

# %% [markdown]
# The cause of missing values can be data corruption or failure to record data. The handling of missing data is very important during the preprocessing of the dataset as many machine learning algorithms do not support missing values.
#
# However, if the dataset is relatively small, every data point counts. In these situations, a missing data point means loss of valuable information. In any case, generally missing data creates imbalanced observations, cause biased estimates, and in extreme cases, can even lead to invalid conclusions.

# %% [markdown]
# ### 7. Describe the various methods for dealing with missing data values in depth.

# %% [markdown]
# - Deleting Rows with missing values
# - Impute missing values for continuous variable
# - Impute missing values for categorical variable
# - Other Imputation Methods
# - Using Algorithms that support missing values
# - Prediction of missing values

# %% [markdown]
# ### 8. What are the various data pre-processing techniques? Explain dimensionality reduction and function selection in a few words.

# %% [markdown]
# 1. Data Cleaning/Cleansing
#
# 2. Data Integration: combines data from multiple sources into a coherent data store
#
# 3. Data Transformation
#
# 4. Data Reduction

# %% [markdown]
# ### 9.  What is the IQR? What criteria are used to assess it? Describe the various components of a box plot in detail? When will the lower whisker    surpass the upper whisker in length? How can box plots be used to identify outliers?

# %% [markdown]
# `IQR (Interquartile range):`
#
# The IQR describes the middle 50% of values when ordered from lowest to highest. To find the interquartile range (IQR), ​first find the median (middle value) of the lower and upper half of the data. These values are quartile 1 (Q1) and quartile 3 (Q3). The IQR is the difference between Q3 and Q1.

# %% [markdown]
# `Box Plot:`
#
# A box and whisker plot—also called a box plot—displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum.
# In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median. The whiskers go from each quartile to the minimum or maximum.
#
#
# ![Screenshot%202022-06-18%20214244.jpg](attachment:Screenshot%202022-06-18%20214244.jpg)

# %% [markdown]
# The Lower whisker surpass the upper when the distribution is left skwed
#
# When reviewing a box plot, an outlier is defined as a data point that is located outside the whiskers of the box plot.

# %% [markdown]
# ### 10. Make brief notes on any two of the following:
#
#      1. Data collected at regular intervals
#
#      2. The gap between the quartiles
#
#      3. Use a cross-tab

# %% [markdown]
# `Interval data:`
#
# Interval Data is measured along a numerical scale that has equal distances between adjacent values. These distances are called “intervals.” There is no true zero on an interval scale, which is what distinguishes it from a ratio scale.
#
# Examples of interval variables include: temperature (Farenheit), temperature (Celcius), pH, SAT score (200-800), credit score (300-850).

# %% [markdown]
# `IQR (Interquartile Range):`
#
# The interquartile range or IQR is the range of the middle half of a set of data. It is the difference between the upper quartile and the lower quartile.

# %% [markdown]
# `Cross-tab:`
#
# A crosstab is a table showing the relationship between two or more variables. Where the table only shows the relationship between two categorical variables, a crosstab is also known as a contingency table.

# %% [markdown]
# ### 11. Make a comparison between:
#
# 1. Data with nominal and ordinal values
#
# 2. Histogram and box plot
#
# 3. The average and median

# %% [markdown]
# `Norminal Data:`
#
#  Nominal data is data that can be labelled or classified into mutually exclusive categories within a variable. These categories cannot be ordered in a meaningful way. For example, for the nominal variable of preferred mode of transportation, you may have the categories of car, bus, train, tram or bicycle.
#
#
#  `Ordinal Data:`
#
# Ordinal data are the type of data in which the values follow a natural order. One of the most notable features of ordinal data is that the differences between the data values cannot be determined or are meaningless. Eg: education level (“high school”,”BS”,”MS”,”PhD”), satisfaction rating (“extremely dislike”, “dislike”, “neutral”, “like”, “extremely like”)

# %% [markdown]
# `Histogram:`
#
# A histogram is a type of bar chart that graphically displays the frequencies of a data set. Similar to a bar chart, a histogram plots the frequency, or raw count, on the Y-axis (vertical) and the variable being measured on the X-axis (horizontal).
#
# `Box plot:`
#
# A box plot, also called a box-and-whisker plot, is a chart that graphically represents the five most important descriptive values for a data set. These values include the minimum value, the first quartile, the median, the third quartile, and the maximum value. When graphing this five-number summary, only the horizontal axis displays values. Within the quadrant, a vertical line is placed above each of the summary numbers. A box is drawn around the middle three lines (first quartile, median, and third quartile) and two lines are drawn from the box’s edges to the two endpoints (minimum and maximum).

# %% [markdown]
# `Average and Median:`
#
# The average is calculated by adding up all of the individual values and dividing this total by the number of observations. The median is calculated by taking the “middle” value, the value for which half of the observations are larger and half are smaller.
#
#
# Average is sensitive to Outliers but median is not affected by outliers
